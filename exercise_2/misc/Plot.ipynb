# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt

# %%
word = ['is',
 'my',
 'this',
 'with',
 '&amp',
 'me',
 'so',
 'are',
 'from',
 'have',
 'just',
 'when',
 'out',
 'love',
 'will',
 'don''t',
 'one',
 'what',
 'as',
 'day']

# %%
count=   [103,
    69,
    58,
    49,
    41,
    38,
    32,
    31,
    30,
    30,
    29,
    26,
    23,
    22,
    21,
    20,
    19,
    19,
    18,
    18]

# %%
y_pos = np.arange(len(word))
plt.bar(y_pos, count, alpha=0.5)
plt.xticks(y_pos, word,rotation=45)
plt.xlabel('Word')
plt.ylabel('Count')
plt.title('Barplot of Most Common Words') 
plt.show()
